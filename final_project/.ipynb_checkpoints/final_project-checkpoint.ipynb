# %%
#overview
"""
This code will have a lot of technical details so I will provide a brief overview of what I am trying to do here:
1. Import all the necessary libraries
2. Set the parameters and initialize the dataframe
3. Calculate the nuclear timescale (M/L) as an order-of-magnitude estimate for comparison with the final integrated lifetime
4. Use the Lane-Emden polytrope equation to define a function for pressure and temperature at a given radius R
5. Define the equation used to determine the reaction rate for the proton-proton chain
6. Integrate over the radius of the star using the pressure and temperature functions from (4) as inputs to the equation in (5)
and multiply by the energy per reaction to get a luminosity
7. Multiply luminosity by the "bin width", and calculate how much total energy was used over this timespan
8. Determine the change in hydrogen mass fraction needed to produce said energy
9. Update the data table with the change in hydrogen mass fraction
10. Repeat steps 4-9 in a recursive algorithm until the hydrogen reaches 0
11. Multiply the length of the data frame by the bin width to get an expected lifespan
12. Compare the result to the prediction made in (3) to get an error value
13. A visualization of the simulation will be available after the algorithm terminates
"""
# Out:
# '\nThis code will have a lot of technical details so I will provide a brief overview of what I am trying to do here:\n1. Import all the necessary libraries\n2. Set the parameters and initialize the dataframe\n3. Calculate the nuclear timescale (M/L) as an order-of-magnitude estimate for comparison with the final integrated lifetime\n4. Use the Lane-Emden polytrope equation to define a function for pressure and temperature at a given radius R\n5. Define the equation used to determine the reaction rate for the proton-proton chain\n6. Integrate over the radius of the star using the pressure and temperature functions from (4) as inputs to the equation in (5)\nand multiply by the energy per reaction to get a luminosity\n7. Multiply luminosity by the "bin width", and calculate how much total energy was used over this timespan\n8. Determine the change in hydrogen mass fraction needed to produce said energy\n9. Update the data table with the change in hydrogen mass fraction\n10. Repeat steps 4-9 in a recursive algorithm until the hydrogen reaches 0\n11. Multiply the length of the data frame by the bin width to get an expected lifespan\n12. Compare the result to the prediction made in (3) to get an error value\n13. A visualization of the simulation will be available after the algorithm terminates\n'

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import scipy as si
import numpy as np
import matplotlib.patches as patches
from matplotlib.widgets import Slider
from scipy.integrate import solve_ivp, simpson
from astropy import constants as const
from astropy import units as u

# %%
#part here to initialize the data frame
"""
parameters
-mass of the star (initial_mass)
-time since simulation started (time_elapsed)
-mass fraction of hydrogen (X)
-mass fraction of helium (Y)
-metallicity (mass fraction of other elements) (Z)
-bin width (bin_width)

assumptions
-Constant mass, luminosity, and radius
-Only red dwarves (100% convective, only P-P chain, only hydrogen fusion)

Users can set the metallicity and mass at the start
"""
bin_width = 10e6 #discrete period over which the simulation runs, in years

time = 0
X = 0.75
Y = 0.25
Z = 0.0
initial_mass = 0.3 #a value between 0.1 and 0.5 solar massess, the mass range for fully convective red dwarfs

#some physical constants from astropy
M_sun = const.M_sun.cgs.value      # g
R_sun = const.R_sun.cgs.value      # cm
L_sun = const.L_sun.cgs.value      # erg/s
G = const.G.cgs.value              # cm³/g/s²
k_B = const.k_B.cgs.value          # erg/K
m_p = const.m_p.cgs.value          # g
c = const.c.cgs.value              # cm/s

columns = ['time', 'X', 'Y', 'Z', 'mass', 'T_core', 'rho_core', 'L', 'R'] #The last 4 variables will be needed for the algorithm and are dependent
initial_data = {
    'time': [time],
    'X': [X],
    'Y': [Y],
    'Z': [Z],
    'mass': [initial_mass],
    'T_core': [np.nan],    # Will calculate in first step
    'rho_core': [np.nan],  # Will calculate in first step
    'L': [np.nan],         # Will calculate in first step
    'R': [np.nan]          # Will calculate in first step
}
main_df = pd.DataFrame(initial_data)

# %%
#Control output 
"""
This cell runs predictions using the sun's known lifespan, the nuclear timescale, and the mass-luminosity relationship of stars to determine
the expected lifespan of the star.

The nuclear timescale uses the fusion rate within a star to relate luminosity to mass. The star "dies" when the fuel has been exhausted,
and thus scales as M/L, or how much the star radiates vs. how much fuel it can burn.
If the luminosity of the star stays constant throughout its lifetime, then luminosity scales roughly as L ~ M^3.5.
(Important note on the above point: the luminosity of the star will drastically increase during the giant phases, so the nuclear timescale
values are typically said to give the main-sequence lifespan of a star, though for the purposes of this project, that will not matter so much,
since red dwarfs never enter the giant phase of their life.)
We can also assume the fuel the star has scales LOCALLY (<0.5 M_sun) proportionally to M. An important nuance here is that the sun, the benchmark star,
does NOT have a fully convective interior, and thus only fuses about 10% of its available hydrogen, whereas a red dwarf is fully convective
and will use all of its available fuel. We need to correct by multiplying the nuclear timescale by 10.

Putting these components together, we get that lifespan goes as M/M^3.5 ~ M^-2.5.

The sun has an expected lifespan of 10^10yr (10Gyr). We can use a simple ratio that takes the mass of the input star and returns its expected lifespan.
"""
def nuclear_timescale(mass):
    return (1 / (mass ** 2.5)) * 1e10 * 10

print(f"{nuclear_timescale(initial_mass):e}")
# Out:
# 2.028602e+12

# %%
#Lane-Emden Equation Class - First component of solving for energy

"""
Model approach: Hydrostatic equilibrium (polytrope)+ energy (nuclear timescale)
To maintain hydrostatic equilibrium, the star must have a certain amount of pressure counteracting gravity at a given radius
We can calculate how much energy is released from each of the main reaction types, and how many of those reactions are occuring

defining functions to update the data frame
lane-emden equations with polytrope index n = 1.5 (appropriate for red dwarf stars)
use polytropic approach for simplifications; need definite integrals
use Runge-Kutta to solve the differential equation

IMPORTANT: Credit to Michael Zingale, whose notebook I referenced for the derivation and code at this link: https://zingale.github.io/stars/notebooks/polytrope/lane-emden.html
"""
class LaneEmdenSolver: #Solves the Lane-Emden equation for a polytrope of index n
    
    def __init__(self, n=1.5):
        self.n = n
        self.xi = None
        self.theta = None
        self.dtheta_dxi = None
        self.xi_surface = None 
    def solve(self, xi_max=10):
        """Solve the Lane-Emden equation from center to surface."""
        # Initial conditions: θ(0)=1, θ'(0)=0
        y0 = [1.0, 0.0]
        
        # Event: stop when theta crosses zero (surface)
        def surface_event(xi, y):
            return y[0]  # theta = 0
        surface_event.terminal = True
        surface_event.direction = -1
        
        # Solve using scipy
        sol = solve_ivp(
            fun=self._lane_emden_derivatives,
            t_span=[1e-6, xi_max],
            y0=y0,
            method='RK45',
            events=surface_event,
            dense_output=True,
            max_step=0.1
        )
        
        # Extract solution
        self.xi = sol.t
        self.theta = sol.y[0]
        self.dtheta_dxi = sol.y[1]
        
        # CRITICAL: Remove any negative theta values
        positive_mask = self.theta > 0
        self.xi = self.xi[positive_mask]
        self.theta = self.theta[positive_mask]
        self.dtheta_dxi = self.dtheta_dxi[positive_mask]
        
        self.xi_surface = self.xi[-1]
        
        print(f"Kept {len(self.xi)} points with positive theta")
        
        return self.xi, self.theta, self.dtheta_dxi
    
    def _lane_emden_derivatives(self, xi, y):
        """Lane-Emden equation derivatives."""
        theta, dtheta = y
        
        # Ensure theta stays positive
        theta = max(theta, 0.0)
        
        # Handle singularity at xi=0
        if xi < 1e-10:
            d2theta = -theta**self.n / 3.0
        else:
            d2theta = -2.0*dtheta/xi - theta**self.n
        
        return [dtheta, d2theta]


def get_stellar_structure(M_solar, X, polytrope_solution):
    """
    Convert Lane-Emden solution to physical stellar structure.
    
    Parameters:
    -----------
    M_solar : float
        Stellar mass in solar masses
    X : float
        Hydrogen mass fraction
    polytrope_solution : LaneEmdenSolver
        Solved Lane-Emden equation
    
    Returns:
    --------
    dict with keys: 'R', 'rho_c', 'T_c', 'r', 'rho', 'T'
    """
    M = M_solar * M_sun
    
    # Mean molecular weight for fully ionized gas
    Y = 1.0 - X
    mu = 1.0 / (2.0*X + 0.75*Y)
    
    # Mass-radius relation for red dwarfs
    R = (M_solar**0.8) * R_sun
    
    # Scaling factor
    alpha = R / polytrope_solution.xi_surface
    
    # Central density from mass normalization
    integrand = polytrope_solution.xi**2 * polytrope_solution.theta**polytrope_solution.n
    integral = simpson(integrand, polytrope_solution.xi)
    rho_c = M / (4.0 * np.pi * alpha**3 * integral)
    
    # Central temperature
    T_virial = G * M * mu * m_p / (k_B * R)
    T_c = 0.6 * T_virial  # Correction factor for n=1.5
    
    # Full profiles
    r = alpha * polytrope_solution.xi
    rho = rho_c * polytrope_solution.theta**polytrope_solution.n
    T = T_c * polytrope_solution.theta
    
    return {
        'R': R,
        'rho_c': rho_c,
        'T_c': T_c,
        'r': r,
        'rho': rho,
        'T': T
    }

# Test the solver
if __name__ == "__main__":
    # Solve Lane-Emden for n=1.5
    solver = LaneEmdenSolver(n=1.5)
    xi, theta, dtheta = solver.solve()
    
    print(f"Lane-Emden solution for n=1.5:")
    print(f"  Surface at ξ = {solver.xi_surface:.4f}")
    print(f"  Expected: ξ ≈ 3.65 for n=1.5")
    
    # Get structure for 0.3 solar mass red dwarf
    structure = get_stellar_structure(0.3, X=0.75, polytrope_solution=solver)
    
    print(f"\nStellar structure for 0.3 M☉:")
    print(f"  Radius: {structure['R']/R_sun:.3f} R☉")
    print(f"  Central density: {structure['rho_c']:.3e} g/cm³")
    print(f"  Central temperature: {structure['T_c']/1e6:.2f} million K")
# Out:
# Kept 44 points with positive theta
# Lane-Emden solution for n=1.5:
#   Surface at ξ = 3.5665
#   Expected: ξ ≈ 3.65 for n=1.5
#
# Stellar structure for 0.3 M☉:
#   Radius: 0.382 R☉
#   Central density: 4.240e+01 g/cm³
#   Central temperature: 6.46 million K

# %%
#The energy generated by the proton-proton chain
"""
Equation derived from this Harvard lecture I found, linked here: https://people.ast.cam.ac.uk/~phewett/SandES2017/Lec2017_11.pdf

"""
def epsilon_pp(rho, T, X):
    """
    PP-chain energy generation rate (CGS units)
    
    From: Clayton (1968), Kippenhahn & Weigert (1990)
    """
    epsilon_0 = 2.4e4  # erg/g/s (CGS)
    T7 = T / 1e7       # Temperature in units of 10^7 K
    
    return epsilon_0 * rho * X**2 * T7**4

# %%
#run the recursive algorithm
"""

"""

def update_composition_simple(L_solar, M_solar, X, Y, dt_years):
    """
    Simpler version: use mass-energy conversion directly.
    
    Parameters:
    -----------
    L_solar : float
        Luminosity in solar luminosities
    M_solar : float
        Stellar mass in solar masses
    X, Y : float
        Current hydrogen and helium fractions
    dt_years : float
        Timestep in years
    
    Returns:
    --------
    X_new, Y_new : float
        Updated mass fractions
    """
    # Energy radiated over timestep
    L_erg_s = L_solar * L_sun
    dt_sec = dt_years * 3.156e7
    E_radiated = L_erg_s * dt_sec  # erg
    
    # Mass-energy relation: E = Δm * c²
    # For H→He: efficiency η = 0.007 (0.7% of mass converts to energy)
    eta = 0.007
    
    # Total hydrogen mass consumed
    M_H_consumed = E_radiated / (eta * c**2)  # grams
    
    # Change in mass fraction
    M_star = M_solar * M_sun
    dX = -M_H_consumed / M_star
    
    # Update
    X_new = X + dX
    Y_new = Y - dX
    
    # Don't let X go negative
    if X_new < 0:
        X_new = 0
        Y_new = 1.0
    
    return X_new, Y_new

def calculate_luminosity(structure, X):
    """Calculate stellar luminosity using standard PP-chain formula"""
    
    r = structure['r']
    rho = structure['rho']
    T = structure['T']
    
    # Standard PP-chain formula (Carroll & Ostlie, Clayton)
    # ε_pp = ε_0 * ρ * X^2 * T_6^ν
    # where T_6 = T/(10^6 K) and ν ≈ 4
    
    T_6 = T / 1e6  # Temperature in millions of Kelvin
    
    # For PP-chain in the range 4-20 million K:
    epsilon_0 = 1.07e-7  # Constant for T_6 units (erg/g/s)
    nu = 4.0
    
    epsilon_pp = epsilon_0 * rho * X**2 * T_6**nu
    
    print(f"\n--- Luminosity Calculation ---")
    print(f"T_6 range: {T_6.min():.4f} to {T_6.max():.4f} (MK)")
    print(f"epsilon_pp range: {epsilon_pp.min():.2e} to {epsilon_pp.max():.2e} erg/g/s")
    
    # Integrate
    integrand = 4.0 * np.pi * r**2 * rho * epsilon_pp
    L_total = simpson(integrand, r)
    L_solar = L_total / L_sun
    
    print(f"L in solar units: {L_solar:.6e}")
    print(f"Expected for 0.3 M_sun: ~0.01-0.05 L_sun")
    print(f"----------------------------\n")
    
    return 10000 * L_solar

# Evolution loop
step = 0
max_steps = 10000  # Safety limit
dt = bin_width

# RESET everything before evolution
time = 0
X = 0.75
Y = 0.25
Z = 0.0
initial_mass = 0.3
dt = 1e8  # 100 million years

step = 0
max_steps = 10000

# Calculate luminosity
L = calculate_luminosity(structure, X)
print(f"LUMINOSITY: {L:.6e} L_sun")
print(f"Expected for 0.3 M_sun: ~0.01 L_sun")

# Also check the structure values
print(f"T_core: {structure['T_c']/1e6:.2f} MK")
print(f"rho_core: {structure['rho_c']:.2e} g/cm³")
print(f"Number of radial points: {len(structure['r'])}")

while X > 0.01 and step < max_steps:
    # Get current stellar structure
    structure = get_stellar_structure(initial_mass, X, solver)
    
    # Calculate luminosity
    L = calculate_luminosity(structure, X)
    
    # Update composition
    X_new, Y_new = update_composition_simple(L, initial_mass, X, Y, dt)
    
    # Update time
    time += dt
    
    # Store in dataframe
    new_row = {
        'time': time / 1e9,  # Convert to Gyr
        'X': X_new,
        'Y': Y_new,
        'Z': Z,
        'mass': initial_mass,
        'T_core': structure['T_c'],
        'rho_core': structure['rho_c'],
        'L': L,
        'R': structure['R'] / R_sun
    }
    main_df = pd.concat([main_df, pd.DataFrame([new_row])], ignore_index=True)
    
    # Update for next iteration
    X = X_new
    Y = Y_new
    step += 1
    
    # Progress update
    if step % 100 == 0:
        print(f"Step {step}: t={time/1e9:.2f} Gyr, X={X:.4f}, L={L:.6f} L☉")

print(f"\nEvolution complete!")
print(f"Total time: {time/1e9:.1f} Gyr")
print(f"Final X: {X:.4f}")
print(f"Steps taken: {step}")
# Out:
# --- Luminosity Calculation ---
# T_6 range: 0.1176 to 6.4679 (MK)
# epsilon_pp range: 1.20e-12 to 4.47e-03 erg/g/s
# L in solar units: 8.711037e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
# LUMINOSITY: 8.711037e-01 L_sun
# Expected for 0.3 M_sun: ~0.01 L_sun
# T_core: 6.47 MK
# rho_core: 4.24e+01 g/cm³
# Number of radial points: 44
#
# --- Luminosity Calculation ---
# T_6 range: 0.1174 to 6.4586 (MK)
# epsilon_pp range: 1.19e-12 to 4.44e-03 erg/g/s
# L in solar units: 8.660609e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1177 to 6.4719 (MK)
# epsilon_pp range: 1.19e-12 to 4.44e-03 erg/g/s
# L in solar units: 8.667721e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1179 to 6.4854 (MK)
# epsilon_pp range: 1.19e-12 to 4.45e-03 erg/g/s
# L in solar units: 8.674750e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1181 to 6.4989 (MK)
# epsilon_pp range: 1.19e-12 to 4.45e-03 erg/g/s
# L in solar units: 8.681697e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1184 to 6.5124 (MK)
# epsilon_pp range: 1.19e-12 to 4.45e-03 erg/g/s
# L in solar units: 8.688559e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1186 to 6.5261 (MK)
# epsilon_pp range: 1.19e-12 to 4.46e-03 erg/g/s
# L in solar units: 8.695335e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1189 to 6.5398 (MK)
# epsilon_pp range: 1.19e-12 to 4.46e-03 erg/g/s
# L in solar units: 8.702022e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1191 to 6.5535 (MK)
# epsilon_pp range: 1.20e-12 to 4.46e-03 erg/g/s
# L in solar units: 8.708619e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1194 to 6.5674 (MK)
# epsilon_pp range: 1.20e-12 to 4.47e-03 erg/g/s
# L in solar units: 8.715124e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1196 to 6.5813 (MK)
# epsilon_pp range: 1.20e-12 to 4.47e-03 erg/g/s
# L in solar units: 8.721535e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1199 to 6.5953 (MK)
# epsilon_pp range: 1.20e-12 to 4.47e-03 erg/g/s
# L in solar units: 8.727851e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1202 to 6.6093 (MK)
# epsilon_pp range: 1.20e-12 to 4.48e-03 erg/g/s
# L in solar units: 8.734069e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1204 to 6.6234 (MK)
# epsilon_pp range: 1.20e-12 to 4.48e-03 erg/g/s
# L in solar units: 8.740188e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1207 to 6.6376 (MK)
# epsilon_pp range: 1.20e-12 to 4.48e-03 erg/g/s
# L in solar units: 8.746205e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1209 to 6.6519 (MK)
# epsilon_pp range: 1.20e-12 to 4.49e-03 erg/g/s
# L in solar units: 8.752119e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1212 to 6.6662 (MK)
# epsilon_pp range: 1.20e-12 to 4.49e-03 erg/g/s
# L in solar units: 8.757927e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1215 to 6.6806 (MK)
# epsilon_pp range: 1.20e-12 to 4.49e-03 erg/g/s
# L in solar units: 8.763629e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1217 to 6.6951 (MK)
# epsilon_pp range: 1.20e-12 to 4.50e-03 erg/g/s
# L in solar units: 8.769221e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1220 to 6.7096 (MK)
# epsilon_pp range: 1.20e-12 to 4.50e-03 erg/g/s
# L in solar units: 8.774701e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1222 to 6.7242 (MK)
# epsilon_pp range: 1.21e-12 to 4.50e-03 erg/g/s
# L in solar units: 8.780068e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1225 to 6.7389 (MK)
# epsilon_pp range: 1.21e-12 to 4.50e-03 erg/g/s
# L in solar units: 8.785319e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1228 to 6.7537 (MK)
# epsilon_pp range: 1.21e-12 to 4.51e-03 erg/g/s
# L in solar units: 8.790453e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1231 to 6.7685 (MK)
# epsilon_pp range: 1.21e-12 to 4.51e-03 erg/g/s
# L in solar units: 8.795467e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1233 to 6.7834 (MK)
# epsilon_pp range: 1.21e-12 to 4.51e-03 erg/g/s
# L in solar units: 8.800358e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1236 to 6.7984 (MK)
# epsilon_pp range: 1.21e-12 to 4.51e-03 erg/g/s
# L in solar units: 8.805125e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1239 to 6.8135 (MK)
# epsilon_pp range: 1.21e-12 to 4.52e-03 erg/g/s
# L in solar units: 8.809766e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1241 to 6.8286 (MK)
# epsilon_pp range: 1.21e-12 to 4.52e-03 erg/g/s
# L in solar units: 8.814277e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1244 to 6.8438 (MK)
# epsilon_pp range: 1.21e-12 to 4.52e-03 erg/g/s
# L in solar units: 8.818658e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1247 to 6.8591 (MK)
# epsilon_pp range: 1.21e-12 to 4.52e-03 erg/g/s
# L in solar units: 8.822905e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1250 to 6.8744 (MK)
# epsilon_pp range: 1.21e-12 to 4.53e-03 erg/g/s
# L in solar units: 8.827017e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1253 to 6.8899 (MK)
# epsilon_pp range: 1.21e-12 to 4.53e-03 erg/g/s
# L in solar units: 8.830990e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1255 to 6.9054 (MK)
# epsilon_pp range: 1.21e-12 to 4.53e-03 erg/g/s
# L in solar units: 8.834823e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1258 to 6.9210 (MK)
# epsilon_pp range: 1.21e-12 to 4.53e-03 erg/g/s
# L in solar units: 8.838513e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1261 to 6.9367 (MK)
# epsilon_pp range: 1.21e-12 to 4.53e-03 erg/g/s
# L in solar units: 8.842057e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1264 to 6.9524 (MK)
# epsilon_pp range: 1.21e-12 to 4.53e-03 erg/g/s
# L in solar units: 8.845454e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1267 to 6.9682 (MK)
# epsilon_pp range: 1.21e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.848701e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1270 to 6.9841 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.851794e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1273 to 7.0001 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.854733e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1276 to 7.0162 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.857514e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1278 to 7.0323 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.860134e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1281 to 7.0485 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.862591e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1284 to 7.0648 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.864882e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1287 to 7.0812 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.867006e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1290 to 7.0976 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.868958e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1293 to 7.1142 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.870737e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1296 to 7.1308 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.872339e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1299 to 7.1475 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.873762e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1302 to 7.1642 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.875004e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1306 to 7.1811 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.876060e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1309 to 7.1980 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.876930e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1312 to 7.2151 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.877609e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1315 to 7.2322 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.878095e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1318 to 7.2494 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.878386e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1321 to 7.2666 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.878478e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1324 to 7.2840 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.878368e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1327 to 7.3014 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.878053e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1331 to 7.3189 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.877532e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1334 to 7.3365 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.876800e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1337 to 7.3542 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.875854e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1340 to 7.3720 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.874693e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1343 to 7.3898 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.873312e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1347 to 7.4078 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.871709e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1350 to 7.4258 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.869881e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1353 to 7.4439 (MK)
# epsilon_pp range: 1.22e-12 to 4.55e-03 erg/g/s
# L in solar units: 8.867825e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1357 to 7.4621 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.865538e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1360 to 7.4803 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.863016e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1363 to 7.4987 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.860258e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1367 to 7.5171 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.857259e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1370 to 7.5356 (MK)
# epsilon_pp range: 1.22e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.854017e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1373 to 7.5543 (MK)
# epsilon_pp range: 1.21e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.850529e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1377 to 7.5730 (MK)
# epsilon_pp range: 1.21e-12 to 4.54e-03 erg/g/s
# L in solar units: 8.846791e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1380 to 7.5917 (MK)
# epsilon_pp range: 1.21e-12 to 4.53e-03 erg/g/s
# L in solar units: 8.842801e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1384 to 7.6106 (MK)
# epsilon_pp range: 1.21e-12 to 4.53e-03 erg/g/s
# L in solar units: 8.838555e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1387 to 7.6295 (MK)
# epsilon_pp range: 1.21e-12 to 4.53e-03 erg/g/s
# L in solar units: 8.834051e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1391 to 7.6486 (MK)
# epsilon_pp range: 1.21e-12 to 4.53e-03 erg/g/s
# L in solar units: 8.829286e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1394 to 7.6677 (MK)
# epsilon_pp range: 1.21e-12 to 4.52e-03 erg/g/s
# L in solar units: 8.824256e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1397 to 7.6869 (MK)
# epsilon_pp range: 1.21e-12 to 4.52e-03 erg/g/s
# L in solar units: 8.818959e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1401 to 7.7062 (MK)
# epsilon_pp range: 1.21e-12 to 4.52e-03 erg/g/s
# L in solar units: 8.813391e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1404 to 7.7256 (MK)
# epsilon_pp range: 1.21e-12 to 4.52e-03 erg/g/s
# L in solar units: 8.807549e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1408 to 7.7450 (MK)
# epsilon_pp range: 1.21e-12 to 4.51e-03 erg/g/s
# L in solar units: 8.801431e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1412 to 7.7646 (MK)
# epsilon_pp range: 1.21e-12 to 4.51e-03 erg/g/s
# L in solar units: 8.795033e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1415 to 7.7842 (MK)
# epsilon_pp range: 1.21e-12 to 4.51e-03 erg/g/s
# L in solar units: 8.788352e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1419 to 7.8039 (MK)
# epsilon_pp range: 1.21e-12 to 4.50e-03 erg/g/s
# L in solar units: 8.781386e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1422 to 7.8237 (MK)
# epsilon_pp range: 1.20e-12 to 4.50e-03 erg/g/s
# L in solar units: 8.774132e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1426 to 7.8436 (MK)
# epsilon_pp range: 1.20e-12 to 4.49e-03 erg/g/s
# L in solar units: 8.766585e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1430 to 7.8635 (MK)
# epsilon_pp range: 1.20e-12 to 4.49e-03 erg/g/s
# L in solar units: 8.758745e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1433 to 7.8836 (MK)
# epsilon_pp range: 1.20e-12 to 4.49e-03 erg/g/s
# L in solar units: 8.750607e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1437 to 7.9037 (MK)
# epsilon_pp range: 1.20e-12 to 4.48e-03 erg/g/s
# L in solar units: 8.742170e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1441 to 7.9239 (MK)
# epsilon_pp range: 1.20e-12 to 4.48e-03 erg/g/s
# L in solar units: 8.733429e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1444 to 7.9442 (MK)
# epsilon_pp range: 1.20e-12 to 4.47e-03 erg/g/s
# L in solar units: 8.724382e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1448 to 7.9646 (MK)
# epsilon_pp range: 1.20e-12 to 4.47e-03 erg/g/s
# L in solar units: 8.715027e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1452 to 7.9851 (MK)
# epsilon_pp range: 1.19e-12 to 4.46e-03 erg/g/s
# L in solar units: 8.705361e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1455 to 8.0056 (MK)
# epsilon_pp range: 1.19e-12 to 4.46e-03 erg/g/s
# L in solar units: 8.695380e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1459 to 8.0262 (MK)
# epsilon_pp range: 1.19e-12 to 4.45e-03 erg/g/s
# L in solar units: 8.685083e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1463 to 8.0470 (MK)
# epsilon_pp range: 1.19e-12 to 4.45e-03 erg/g/s
# L in solar units: 8.674466e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1467 to 8.0677 (MK)
# epsilon_pp range: 1.19e-12 to 4.44e-03 erg/g/s
# L in solar units: 8.663528e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1471 to 8.0886 (MK)
# epsilon_pp range: 1.19e-12 to 4.44e-03 erg/g/s
# L in solar units: 8.652264e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1474 to 8.1096 (MK)
# epsilon_pp range: 1.19e-12 to 4.43e-03 erg/g/s
# L in solar units: 8.640674e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1478 to 8.1306 (MK)
# epsilon_pp range: 1.18e-12 to 4.42e-03 erg/g/s
# L in solar units: 8.628754e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1482 to 8.1517 (MK)
# epsilon_pp range: 1.18e-12 to 4.42e-03 erg/g/s
# L in solar units: 8.616501e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
# Step 100: t=10.00 Gyr, X=0.4668, L=0.861650 L☉
#
# --- Luminosity Calculation ---
# T_6 range: 0.1486 to 8.1729 (MK)
# epsilon_pp range: 1.18e-12 to 4.41e-03 erg/g/s
# L in solar units: 8.603915e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1490 to 8.1942 (MK)
# epsilon_pp range: 1.18e-12 to 4.40e-03 erg/g/s
# L in solar units: 8.590991e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1494 to 8.2155 (MK)
# epsilon_pp range: 1.18e-12 to 4.40e-03 erg/g/s
# L in solar units: 8.577729e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1497 to 8.2370 (MK)
# epsilon_pp range: 1.18e-12 to 4.39e-03 erg/g/s
# L in solar units: 8.564125e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1501 to 8.2585 (MK)
# epsilon_pp range: 1.17e-12 to 4.38e-03 erg/g/s
# L in solar units: 8.550178e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1505 to 8.2801 (MK)
# epsilon_pp range: 1.17e-12 to 4.38e-03 erg/g/s
# L in solar units: 8.535885e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1509 to 8.3017 (MK)
# epsilon_pp range: 1.17e-12 to 4.37e-03 erg/g/s
# L in solar units: 8.521245e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1513 to 8.3235 (MK)
# epsilon_pp range: 1.17e-12 to 4.36e-03 erg/g/s
# L in solar units: 8.506256e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1517 to 8.3453 (MK)
# epsilon_pp range: 1.17e-12 to 4.35e-03 erg/g/s
# L in solar units: 8.490914e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1521 to 8.3672 (MK)
# epsilon_pp range: 1.16e-12 to 4.34e-03 erg/g/s
# L in solar units: 8.475220e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1525 to 8.3891 (MK)
# epsilon_pp range: 1.16e-12 to 4.34e-03 erg/g/s
# L in solar units: 8.459171e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1529 to 8.4112 (MK)
# epsilon_pp range: 1.16e-12 to 4.33e-03 erg/g/s
# L in solar units: 8.442765e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1533 to 8.4333 (MK)
# epsilon_pp range: 1.16e-12 to 4.32e-03 erg/g/s
# L in solar units: 8.426001e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1537 to 8.4555 (MK)
# epsilon_pp range: 1.15e-12 to 4.31e-03 erg/g/s
# L in solar units: 8.408877e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1541 to 8.4777 (MK)
# epsilon_pp range: 1.15e-12 to 4.30e-03 erg/g/s
# L in solar units: 8.391392e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1545 to 8.5001 (MK)
# epsilon_pp range: 1.15e-12 to 4.29e-03 erg/g/s
# L in solar units: 8.373544e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1549 to 8.5225 (MK)
# epsilon_pp range: 1.15e-12 to 4.28e-03 erg/g/s
# L in solar units: 8.355333e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1553 to 8.5449 (MK)
# epsilon_pp range: 1.14e-12 to 4.27e-03 erg/g/s
# L in solar units: 8.336757e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1558 to 8.5675 (MK)
# epsilon_pp range: 1.14e-12 to 4.26e-03 erg/g/s
# L in solar units: 8.317815e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1562 to 8.5901 (MK)
# epsilon_pp range: 1.14e-12 to 4.25e-03 erg/g/s
# L in solar units: 8.298506e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1566 to 8.6127 (MK)
# epsilon_pp range: 1.14e-12 to 4.24e-03 erg/g/s
# L in solar units: 8.278830e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1570 to 8.6355 (MK)
# epsilon_pp range: 1.13e-12 to 4.23e-03 erg/g/s
# L in solar units: 8.258785e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1574 to 8.6583 (MK)
# epsilon_pp range: 1.13e-12 to 4.22e-03 erg/g/s
# L in solar units: 8.238371e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1578 to 8.6811 (MK)
# epsilon_pp range: 1.13e-12 to 4.21e-03 erg/g/s
# L in solar units: 8.217587e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1582 to 8.7040 (MK)
# epsilon_pp range: 1.13e-12 to 4.20e-03 erg/g/s
# L in solar units: 8.196433e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1587 to 8.7270 (MK)
# epsilon_pp range: 1.12e-12 to 4.19e-03 erg/g/s
# L in solar units: 8.174909e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1591 to 8.7501 (MK)
# epsilon_pp range: 1.12e-12 to 4.18e-03 erg/g/s
# L in solar units: 8.153014e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1595 to 8.7732 (MK)
# epsilon_pp range: 1.12e-12 to 4.17e-03 erg/g/s
# L in solar units: 8.130748e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1599 to 8.7963 (MK)
# epsilon_pp range: 1.11e-12 to 4.16e-03 erg/g/s
# L in solar units: 8.108112e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1603 to 8.8196 (MK)
# epsilon_pp range: 1.11e-12 to 4.14e-03 erg/g/s
# L in solar units: 8.085106e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1608 to 8.8429 (MK)
# epsilon_pp range: 1.11e-12 to 4.13e-03 erg/g/s
# L in solar units: 8.061729e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1612 to 8.8662 (MK)
# epsilon_pp range: 1.10e-12 to 4.12e-03 erg/g/s
# L in solar units: 8.037982e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1616 to 8.8896 (MK)
# epsilon_pp range: 1.10e-12 to 4.11e-03 erg/g/s
# L in solar units: 8.013866e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1620 to 8.9130 (MK)
# epsilon_pp range: 1.10e-12 to 4.10e-03 erg/g/s
# L in solar units: 7.989382e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1625 to 8.9365 (MK)
# epsilon_pp range: 1.09e-12 to 4.08e-03 erg/g/s
# L in solar units: 7.964529e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1629 to 8.9601 (MK)
# epsilon_pp range: 1.09e-12 to 4.07e-03 erg/g/s
# L in solar units: 7.939310e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1633 to 8.9837 (MK)
# epsilon_pp range: 1.09e-12 to 4.06e-03 erg/g/s
# L in solar units: 7.913725e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1638 to 9.0073 (MK)
# epsilon_pp range: 1.08e-12 to 4.04e-03 erg/g/s
# L in solar units: 7.887775e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1642 to 9.0310 (MK)
# epsilon_pp range: 1.08e-12 to 4.03e-03 erg/g/s
# L in solar units: 7.861462e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1646 to 9.0547 (MK)
# epsilon_pp range: 1.08e-12 to 4.02e-03 erg/g/s
# L in solar units: 7.834787e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1650 to 9.0785 (MK)
# epsilon_pp range: 1.07e-12 to 4.00e-03 erg/g/s
# L in solar units: 7.807752e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1655 to 9.1023 (MK)
# epsilon_pp range: 1.07e-12 to 3.99e-03 erg/g/s
# L in solar units: 7.780358e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1659 to 9.1262 (MK)
# epsilon_pp range: 1.06e-12 to 3.97e-03 erg/g/s
# L in solar units: 7.752607e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1663 to 9.1501 (MK)
# epsilon_pp range: 1.06e-12 to 3.96e-03 erg/g/s
# L in solar units: 7.724502e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1668 to 9.1740 (MK)
# epsilon_pp range: 1.06e-12 to 3.95e-03 erg/g/s
# L in solar units: 7.696045e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1672 to 9.1980 (MK)
# epsilon_pp range: 1.05e-12 to 3.93e-03 erg/g/s
# L in solar units: 7.667237e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1677 to 9.2220 (MK)
# epsilon_pp range: 1.05e-12 to 3.92e-03 erg/g/s
# L in solar units: 7.638082e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1681 to 9.2461 (MK)
# epsilon_pp range: 1.04e-12 to 3.90e-03 erg/g/s
# L in solar units: 7.608582e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1685 to 9.2701 (MK)
# epsilon_pp range: 1.04e-12 to 3.89e-03 erg/g/s
# L in solar units: 7.578739e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1690 to 9.2943 (MK)
# epsilon_pp range: 1.04e-12 to 3.87e-03 erg/g/s
# L in solar units: 7.548557e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1694 to 9.3184 (MK)
# epsilon_pp range: 1.03e-12 to 3.85e-03 erg/g/s
# L in solar units: 7.518039e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1698 to 9.3426 (MK)
# epsilon_pp range: 1.03e-12 to 3.84e-03 erg/g/s
# L in solar units: 7.487187e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1703 to 9.3667 (MK)
# epsilon_pp range: 1.02e-12 to 3.82e-03 erg/g/s
# L in solar units: 7.456006e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1707 to 9.3910 (MK)
# epsilon_pp range: 1.02e-12 to 3.81e-03 erg/g/s
# L in solar units: 7.424498e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1712 to 9.4152 (MK)
# epsilon_pp range: 1.01e-12 to 3.79e-03 erg/g/s
# L in solar units: 7.392668e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1716 to 9.4395 (MK)
# epsilon_pp range: 1.01e-12 to 3.77e-03 erg/g/s
# L in solar units: 7.360518e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1720 to 9.4637 (MK)
# epsilon_pp range: 1.01e-12 to 3.76e-03 erg/g/s
# L in solar units: 7.328054e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1725 to 9.4880 (MK)
# epsilon_pp range: 1.00e-12 to 3.74e-03 erg/g/s
# L in solar units: 7.295278e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1729 to 9.5123 (MK)
# epsilon_pp range: 9.97e-13 to 3.72e-03 erg/g/s
# L in solar units: 7.262195e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1734 to 9.5367 (MK)
# epsilon_pp range: 9.92e-13 to 3.71e-03 erg/g/s
# L in solar units: 7.228810e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1738 to 9.5610 (MK)
# epsilon_pp range: 9.88e-13 to 3.69e-03 erg/g/s
# L in solar units: 7.195127e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1743 to 9.5853 (MK)
# epsilon_pp range: 9.83e-13 to 3.67e-03 erg/g/s
# L in solar units: 7.161150e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1747 to 9.6097 (MK)
# epsilon_pp range: 9.78e-13 to 3.65e-03 erg/g/s
# L in solar units: 7.126885e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1751 to 9.6341 (MK)
# epsilon_pp range: 9.74e-13 to 3.64e-03 erg/g/s
# L in solar units: 7.092335e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1756 to 9.6584 (MK)
# epsilon_pp range: 9.69e-13 to 3.62e-03 erg/g/s
# L in solar units: 7.057507e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1760 to 9.6828 (MK)
# epsilon_pp range: 9.64e-13 to 3.60e-03 erg/g/s
# L in solar units: 7.022405e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1765 to 9.7072 (MK)
# epsilon_pp range: 9.59e-13 to 3.58e-03 erg/g/s
# L in solar units: 6.987034e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1769 to 9.7315 (MK)
# epsilon_pp range: 9.54e-13 to 3.56e-03 erg/g/s
# L in solar units: 6.951400e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1774 to 9.7559 (MK)
# epsilon_pp range: 9.49e-13 to 3.55e-03 erg/g/s
# L in solar units: 6.915509e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1778 to 9.7803 (MK)
# epsilon_pp range: 9.44e-13 to 3.53e-03 erg/g/s
# L in solar units: 6.879365e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1782 to 9.8046 (MK)
# epsilon_pp range: 9.39e-13 to 3.51e-03 erg/g/s
# L in solar units: 6.842975e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1787 to 9.8290 (MK)
# epsilon_pp range: 9.34e-13 to 3.49e-03 erg/g/s
# L in solar units: 6.806345e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1791 to 9.8533 (MK)
# epsilon_pp range: 9.29e-13 to 3.47e-03 erg/g/s
# L in solar units: 6.769480e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1796 to 9.8776 (MK)
# epsilon_pp range: 9.24e-13 to 3.45e-03 erg/g/s
# L in solar units: 6.732386e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1800 to 9.9019 (MK)
# epsilon_pp range: 9.19e-13 to 3.43e-03 erg/g/s
# L in solar units: 6.695070e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1805 to 9.9262 (MK)
# epsilon_pp range: 9.14e-13 to 3.41e-03 erg/g/s
# L in solar units: 6.657538e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1809 to 9.9505 (MK)
# epsilon_pp range: 9.09e-13 to 3.39e-03 erg/g/s
# L in solar units: 6.619796e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1813 to 9.9748 (MK)
# epsilon_pp range: 9.03e-13 to 3.37e-03 erg/g/s
# L in solar units: 6.581851e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1818 to 9.9990 (MK)
# epsilon_pp range: 8.98e-13 to 3.35e-03 erg/g/s
# L in solar units: 6.543708e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1822 to 10.0232 (MK)
# epsilon_pp range: 8.93e-13 to 3.33e-03 erg/g/s
# L in solar units: 6.505376e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1827 to 10.0474 (MK)
# epsilon_pp range: 8.88e-13 to 3.32e-03 erg/g/s
# L in solar units: 6.466860e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1831 to 10.0716 (MK)
# epsilon_pp range: 8.82e-13 to 3.30e-03 erg/g/s
# L in solar units: 6.428167e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1835 to 10.0957 (MK)
# epsilon_pp range: 8.77e-13 to 3.28e-03 erg/g/s
# L in solar units: 6.389304e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1840 to 10.1198 (MK)
# epsilon_pp range: 8.72e-13 to 3.26e-03 erg/g/s
# L in solar units: 6.350278e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1844 to 10.1439 (MK)
# epsilon_pp range: 8.66e-13 to 3.24e-03 erg/g/s
# L in solar units: 6.311096e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1849 to 10.1679 (MK)
# epsilon_pp range: 8.61e-13 to 3.22e-03 erg/g/s
# L in solar units: 6.271765e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1853 to 10.1919 (MK)
# epsilon_pp range: 8.56e-13 to 3.19e-03 erg/g/s
# L in solar units: 6.232292e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1857 to 10.2159 (MK)
# epsilon_pp range: 8.50e-13 to 3.17e-03 erg/g/s
# L in solar units: 6.192683e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1862 to 10.2398 (MK)
# epsilon_pp range: 8.45e-13 to 3.15e-03 erg/g/s
# L in solar units: 6.152947e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1866 to 10.2637 (MK)
# epsilon_pp range: 8.39e-13 to 3.13e-03 erg/g/s
# L in solar units: 6.113090e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1870 to 10.2875 (MK)
# epsilon_pp range: 8.34e-13 to 3.11e-03 erg/g/s
# L in solar units: 6.073120e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1875 to 10.3113 (MK)
# epsilon_pp range: 8.28e-13 to 3.09e-03 erg/g/s
# L in solar units: 6.033044e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1879 to 10.3350 (MK)
# epsilon_pp range: 8.23e-13 to 3.07e-03 erg/g/s
# L in solar units: 5.992868e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1883 to 10.3587 (MK)
# epsilon_pp range: 8.17e-13 to 3.05e-03 erg/g/s
# L in solar units: 5.952601e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1887 to 10.3823 (MK)
# epsilon_pp range: 8.12e-13 to 3.03e-03 erg/g/s
# L in solar units: 5.912250e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1892 to 10.4059 (MK)
# epsilon_pp range: 8.06e-13 to 3.01e-03 erg/g/s
# L in solar units: 5.871822e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1896 to 10.4294 (MK)
# epsilon_pp range: 8.00e-13 to 2.99e-03 erg/g/s
# L in solar units: 5.831324e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1900 to 10.4529 (MK)
# epsilon_pp range: 7.95e-13 to 2.97e-03 erg/g/s
# L in solar units: 5.790764e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1905 to 10.4763 (MK)
# epsilon_pp range: 7.89e-13 to 2.95e-03 erg/g/s
# L in solar units: 5.750148e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1909 to 10.4997 (MK)
# epsilon_pp range: 7.84e-13 to 2.93e-03 erg/g/s
# L in solar units: 5.709485e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
# Step 200: t=20.00 Gyr, X=0.2286, L=0.570949 L☉
#
# --- Luminosity Calculation ---
# T_6 range: 0.1913 to 10.5230 (MK)
# epsilon_pp range: 7.78e-13 to 2.91e-03 erg/g/s
# L in solar units: 5.668782e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1917 to 10.5462 (MK)
# epsilon_pp range: 7.73e-13 to 2.89e-03 erg/g/s
# L in solar units: 5.628045e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1921 to 10.5694 (MK)
# epsilon_pp range: 7.67e-13 to 2.86e-03 erg/g/s
# L in solar units: 5.587282e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1926 to 10.5925 (MK)
# epsilon_pp range: 7.61e-13 to 2.84e-03 erg/g/s
# L in solar units: 5.546501e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1930 to 10.6155 (MK)
# epsilon_pp range: 7.56e-13 to 2.82e-03 erg/g/s
# L in solar units: 5.505708e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1934 to 10.6384 (MK)
# epsilon_pp range: 7.50e-13 to 2.80e-03 erg/g/s
# L in solar units: 5.464910e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1938 to 10.6613 (MK)
# epsilon_pp range: 7.45e-13 to 2.78e-03 erg/g/s
# L in solar units: 5.424116e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1942 to 10.6841 (MK)
# epsilon_pp range: 7.39e-13 to 2.76e-03 erg/g/s
# L in solar units: 5.383330e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1946 to 10.7069 (MK)
# epsilon_pp range: 7.33e-13 to 2.74e-03 erg/g/s
# L in solar units: 5.342562e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1951 to 10.7295 (MK)
# epsilon_pp range: 7.28e-13 to 2.72e-03 erg/g/s
# L in solar units: 5.301817e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1955 to 10.7521 (MK)
# epsilon_pp range: 7.22e-13 to 2.70e-03 erg/g/s
# L in solar units: 5.261103e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1959 to 10.7746 (MK)
# epsilon_pp range: 7.17e-13 to 2.68e-03 erg/g/s
# L in solar units: 5.220426e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1963 to 10.7970 (MK)
# epsilon_pp range: 7.11e-13 to 2.66e-03 erg/g/s
# L in solar units: 5.179793e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1967 to 10.8194 (MK)
# epsilon_pp range: 7.05e-13 to 2.63e-03 erg/g/s
# L in solar units: 5.139211e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1971 to 10.8416 (MK)
# epsilon_pp range: 7.00e-13 to 2.61e-03 erg/g/s
# L in solar units: 5.098686e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1975 to 10.8638 (MK)
# epsilon_pp range: 6.94e-13 to 2.59e-03 erg/g/s
# L in solar units: 5.058225e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1979 to 10.8859 (MK)
# epsilon_pp range: 6.89e-13 to 2.57e-03 erg/g/s
# L in solar units: 5.017834e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1983 to 10.9079 (MK)
# epsilon_pp range: 6.83e-13 to 2.55e-03 erg/g/s
# L in solar units: 4.977520e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1987 to 10.9298 (MK)
# epsilon_pp range: 6.78e-13 to 2.53e-03 erg/g/s
# L in solar units: 4.937289e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1991 to 10.9516 (MK)
# epsilon_pp range: 6.72e-13 to 2.51e-03 erg/g/s
# L in solar units: 4.897147e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1995 to 10.9733 (MK)
# epsilon_pp range: 6.67e-13 to 2.49e-03 erg/g/s
# L in solar units: 4.857100e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.1999 to 10.9950 (MK)
# epsilon_pp range: 6.61e-13 to 2.47e-03 erg/g/s
# L in solar units: 4.817154e-05
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# ...
# epsilon_pp range: 6.04e-15 to 2.26e-05 erg/g/s
# L in solar units: 4.402483e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2716 (MK)
# epsilon_pp range: 6.03e-15 to 2.25e-05 erg/g/s
# L in solar units: 4.391504e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2719 (MK)
# epsilon_pp range: 6.01e-15 to 2.25e-05 erg/g/s
# L in solar units: 4.380565e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2723 (MK)
# epsilon_pp range: 6.00e-15 to 2.24e-05 erg/g/s
# L in solar units: 4.369665e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2726 (MK)
# epsilon_pp range: 5.98e-15 to 2.23e-05 erg/g/s
# L in solar units: 4.358805e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2729 (MK)
# epsilon_pp range: 5.97e-15 to 2.23e-05 erg/g/s
# L in solar units: 4.347985e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2732 (MK)
# epsilon_pp range: 5.95e-15 to 2.22e-05 erg/g/s
# L in solar units: 4.337203e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2736 (MK)
# epsilon_pp range: 5.94e-15 to 2.22e-05 erg/g/s
# L in solar units: 4.326461e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2739 (MK)
# epsilon_pp range: 5.92e-15 to 2.21e-05 erg/g/s
# L in solar units: 4.315758e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2742 (MK)
# epsilon_pp range: 5.91e-15 to 2.21e-05 erg/g/s
# L in solar units: 4.305094e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2745 (MK)
# epsilon_pp range: 5.89e-15 to 2.20e-05 erg/g/s
# L in solar units: 4.294467e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2749 (MK)
# epsilon_pp range: 5.88e-15 to 2.20e-05 erg/g/s
# L in solar units: 4.283880e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2752 (MK)
# epsilon_pp range: 5.87e-15 to 2.19e-05 erg/g/s
# L in solar units: 4.273330e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2755 (MK)
# epsilon_pp range: 5.85e-15 to 2.19e-05 erg/g/s
# L in solar units: 4.262819e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2758 (MK)
# epsilon_pp range: 5.84e-15 to 2.18e-05 erg/g/s
# L in solar units: 4.252345e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2762 (MK)
# epsilon_pp range: 5.82e-15 to 2.17e-05 erg/g/s
# L in solar units: 4.241909e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2595 to 14.2765 (MK)
# epsilon_pp range: 5.81e-15 to 2.17e-05 erg/g/s
# L in solar units: 4.231510e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2768 (MK)
# epsilon_pp range: 5.79e-15 to 2.16e-05 erg/g/s
# L in solar units: 4.221149e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2771 (MK)
# epsilon_pp range: 5.78e-15 to 2.16e-05 erg/g/s
# L in solar units: 4.210824e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2774 (MK)
# epsilon_pp range: 5.77e-15 to 2.15e-05 erg/g/s
# L in solar units: 4.200537e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2777 (MK)
# epsilon_pp range: 5.75e-15 to 2.15e-05 erg/g/s
# L in solar units: 4.190286e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2781 (MK)
# epsilon_pp range: 5.74e-15 to 2.14e-05 erg/g/s
# L in solar units: 4.180072e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2784 (MK)
# epsilon_pp range: 5.72e-15 to 2.14e-05 erg/g/s
# L in solar units: 4.169895e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2787 (MK)
# epsilon_pp range: 5.71e-15 to 2.13e-05 erg/g/s
# L in solar units: 4.159753e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2790 (MK)
# epsilon_pp range: 5.70e-15 to 2.13e-05 erg/g/s
# L in solar units: 4.149648e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2793 (MK)
# epsilon_pp range: 5.68e-15 to 2.12e-05 erg/g/s
# L in solar units: 4.139579e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
# Step 1100: t=110.00 Gyr, X=0.0106, L=0.004140 L☉
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2796 (MK)
# epsilon_pp range: 5.67e-15 to 2.12e-05 erg/g/s
# L in solar units: 4.129545e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2799 (MK)
# epsilon_pp range: 5.65e-15 to 2.11e-05 erg/g/s
# L in solar units: 4.119547e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2802 (MK)
# epsilon_pp range: 5.64e-15 to 2.11e-05 erg/g/s
# L in solar units: 4.109584e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2806 (MK)
# epsilon_pp range: 5.63e-15 to 2.10e-05 erg/g/s
# L in solar units: 4.099657e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2809 (MK)
# epsilon_pp range: 5.61e-15 to 2.10e-05 erg/g/s
# L in solar units: 4.089764e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2812 (MK)
# epsilon_pp range: 5.60e-15 to 2.09e-05 erg/g/s
# L in solar units: 4.079907e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2815 (MK)
# epsilon_pp range: 5.59e-15 to 2.09e-05 erg/g/s
# L in solar units: 4.070084e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2818 (MK)
# epsilon_pp range: 5.57e-15 to 2.08e-05 erg/g/s
# L in solar units: 4.060296e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2596 to 14.2821 (MK)
# epsilon_pp range: 5.56e-15 to 2.08e-05 erg/g/s
# L in solar units: 4.050542e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2824 (MK)
# epsilon_pp range: 5.55e-15 to 2.07e-05 erg/g/s
# L in solar units: 4.040823e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2827 (MK)
# epsilon_pp range: 5.53e-15 to 2.07e-05 erg/g/s
# L in solar units: 4.031138e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2830 (MK)
# epsilon_pp range: 5.52e-15 to 2.06e-05 erg/g/s
# L in solar units: 4.021486e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2833 (MK)
# epsilon_pp range: 5.51e-15 to 2.06e-05 erg/g/s
# L in solar units: 4.011869e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2836 (MK)
# epsilon_pp range: 5.49e-15 to 2.05e-05 erg/g/s
# L in solar units: 4.002285e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2839 (MK)
# epsilon_pp range: 5.48e-15 to 2.05e-05 erg/g/s
# L in solar units: 3.992735e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2842 (MK)
# epsilon_pp range: 5.47e-15 to 2.04e-05 erg/g/s
# L in solar units: 3.983218e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2845 (MK)
# epsilon_pp range: 5.45e-15 to 2.04e-05 erg/g/s
# L in solar units: 3.973734e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2848 (MK)
# epsilon_pp range: 5.44e-15 to 2.03e-05 erg/g/s
# L in solar units: 3.964283e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2851 (MK)
# epsilon_pp range: 5.43e-15 to 2.03e-05 erg/g/s
# L in solar units: 3.954865e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2854 (MK)
# epsilon_pp range: 5.42e-15 to 2.02e-05 erg/g/s
# L in solar units: 3.945480e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2857 (MK)
# epsilon_pp range: 5.40e-15 to 2.02e-05 erg/g/s
# L in solar units: 3.936128e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2860 (MK)
# epsilon_pp range: 5.39e-15 to 2.01e-05 erg/g/s
# L in solar units: 3.926808e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2863 (MK)
# epsilon_pp range: 5.38e-15 to 2.01e-05 erg/g/s
# L in solar units: 3.917520e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2866 (MK)
# epsilon_pp range: 5.36e-15 to 2.00e-05 erg/g/s
# L in solar units: 3.908264e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2869 (MK)
# epsilon_pp range: 5.35e-15 to 2.00e-05 erg/g/s
# L in solar units: 3.899041e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2872 (MK)
# epsilon_pp range: 5.34e-15 to 1.99e-05 erg/g/s
# L in solar units: 3.889849e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2875 (MK)
# epsilon_pp range: 5.33e-15 to 1.99e-05 erg/g/s
# L in solar units: 3.880689e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2597 to 14.2878 (MK)
# epsilon_pp range: 5.31e-15 to 1.98e-05 erg/g/s
# L in solar units: 3.871560e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2881 (MK)
# epsilon_pp range: 5.30e-15 to 1.98e-05 erg/g/s
# L in solar units: 3.862463e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2884 (MK)
# epsilon_pp range: 5.29e-15 to 1.98e-05 erg/g/s
# L in solar units: 3.853398e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2886 (MK)
# epsilon_pp range: 5.28e-15 to 1.97e-05 erg/g/s
# L in solar units: 3.844363e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2889 (MK)
# epsilon_pp range: 5.26e-15 to 1.97e-05 erg/g/s
# L in solar units: 3.835359e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2892 (MK)
# epsilon_pp range: 5.25e-15 to 1.96e-05 erg/g/s
# L in solar units: 3.826387e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2895 (MK)
# epsilon_pp range: 5.24e-15 to 1.96e-05 erg/g/s
# L in solar units: 3.817445e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2898 (MK)
# epsilon_pp range: 5.23e-15 to 1.95e-05 erg/g/s
# L in solar units: 3.808533e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2901 (MK)
# epsilon_pp range: 5.22e-15 to 1.95e-05 erg/g/s
# L in solar units: 3.799653e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2904 (MK)
# epsilon_pp range: 5.20e-15 to 1.94e-05 erg/g/s
# L in solar units: 3.790802e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2907 (MK)
# epsilon_pp range: 5.19e-15 to 1.94e-05 erg/g/s
# L in solar units: 3.781982e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2909 (MK)
# epsilon_pp range: 5.18e-15 to 1.93e-05 erg/g/s
# L in solar units: 3.773191e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2912 (MK)
# epsilon_pp range: 5.17e-15 to 1.93e-05 erg/g/s
# L in solar units: 3.764431e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2915 (MK)
# epsilon_pp range: 5.16e-15 to 1.93e-05 erg/g/s
# L in solar units: 3.755700e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2918 (MK)
# epsilon_pp range: 5.14e-15 to 1.92e-05 erg/g/s
# L in solar units: 3.746999e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2921 (MK)
# epsilon_pp range: 5.13e-15 to 1.92e-05 erg/g/s
# L in solar units: 3.738328e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2924 (MK)
# epsilon_pp range: 5.12e-15 to 1.91e-05 erg/g/s
# L in solar units: 3.729686e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2926 (MK)
# epsilon_pp range: 5.11e-15 to 1.91e-05 erg/g/s
# L in solar units: 3.721073e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2929 (MK)
# epsilon_pp range: 5.10e-15 to 1.90e-05 erg/g/s
# L in solar units: 3.712489e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2598 to 14.2932 (MK)
# epsilon_pp range: 5.08e-15 to 1.90e-05 erg/g/s
# L in solar units: 3.703935e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# --- Luminosity Calculation ---
# T_6 range: 0.2599 to 14.2935 (MK)
# epsilon_pp range: 5.07e-15 to 1.89e-05 erg/g/s
# L in solar units: 3.695409e-07
# Expected for 0.3 M_sun: ~0.01-0.05 L_sun
# ----------------------------
#
#
# Evolution complete!
# Total time: 114.8 Gyr
# Final X: 0.0100
# Steps taken: 1148

# %%
#code to produce the real-time visuals
"""
this part will work by plotting the stellar core on a 2D cartesian grid as rings of elements
as a simplification (just for visuals), the radius of each ring is just linearly proportional to the fraction of elements, instead of calculating volume
i.e.
r1 = X+Y+Z, r2 = Y+Z, r3 = Z
how to make a real-time sim? how to make a slider to go back and forth on the timeline?
how to plot circle & change color? likely matplotlib library
"""
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.widgets import Slider
import numpy as np

# Example data - replace with your actual simulation data
# Each row: [time (in Myr), X, Y, Z]
simulation_data = np.array([
    [0, 0.70, 0.28, 0.02],
    [100, 0.65, 0.32, 0.03],
    [200, 0.60, 0.36, 0.04],
    [300, 0.55, 0.40, 0.05],
    [400, 0.50, 0.44, 0.06],
    [500, 0.45, 0.47, 0.08],
    [600, 0.40, 0.50, 0.10],
])

# Enable interactive mode
plt.ion()

def plot_core(time_index, ax):
    """Plot the stellar core composition at a given time index"""
    ax.clear()
    
    # Get data for this timestep
    time, X, Y, Z = simulation_data[time_index]
    
    # Calculate radii (based on your spec)
    r1 = X
    r2 = X + Y
    r3 = 1.0  # X + Y + Z should equal 1
    
    # Create circles (plot from outside-in for proper layering)
    # Metals (outermost)
    circle3 = patches.Circle((0, 0), r3, color='blue', label='Metals (Z)')
    ax.add_patch(circle3)
    
    # Helium (middle)
    circle2 = patches.Circle((0, 0), r2, color='orange', label='Helium (Y)')
    ax.add_patch(circle2)
    
    # Hydrogen (innermost)
    circle1 = patches.Circle((0, 0), r1, color='red', label='Hydrogen (X)')
    ax.add_patch(circle1)
    
    # Set axis properties
    ax.set_xlim(-1.2, 1.2)
    ax.set_ylim(-1.2, 1.2)
    ax.set_aspect('equal')
    ax.set_title(f'Stellar Core Composition at t={time:.1f} Myr', fontsize=14)
    ax.legend(loc='upper right')
    
    # Hide axes
    ax.axis('off')
    
    # Add text showing fractions
    ax.text(0, -1.4, f'X={X:.3f}, Y={Y:.3f}, Z={Z:.3f}', 
            ha='center', fontsize=10)

# Setup the figure and axis
fig = plt.figure(figsize=(8, 9))
ax = fig.add_axes([0.1, 0.25, 0.8, 0.65])  # [left, bottom, width, height]

# Initial plot
plot_core(0, ax)

# Create slider for timeline scrubbing
ax_slider = fig.add_axes([0.2, 0.1, 0.6, 0.03])
time_slider = Slider(
    ax=ax_slider,
    label='Time Step',
    valmin=0,
    valmax=len(simulation_data) - 1,
    valinit=0,
    valstep=1
)

# Update function for slider
def update(val):
    time_index = int(time_slider.val)
    plot_core(time_index, ax)
    fig.canvas.draw_idle()

time_slider.on_changed(update)

plt.show()
