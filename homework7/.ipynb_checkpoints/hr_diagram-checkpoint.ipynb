# %%
import numpy as np
import matplotlib as plt

# %%
data = np.loadtxt("../../course_assignments/homework7/star_data.txt", skiprows=1)

# %%
print(data)
# Out:
# [[   9.27    4745.14042]
#  [   8.65    5347.89507]
#  [  10.78    4409.23403]
#  ...
#  [   8.16    5771.1255 ]
#  [   7.72    6116.29924]
#  [  11.85    3965.17868]]
