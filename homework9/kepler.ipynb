# %%
#3.2
import numpy as np
import pandas as pd

#3.3
solar_data = pd.read_csv('solar_system.csv')

#3.4
print(solar_data.shape)
print(solar_data.head())
#there are 20 rows and 11 columns, containing the attributes column and the 9 planets (inc pluto!)

#3.5
orbital_period = solar_data['orbital_period'].astype(float)
perihelion = solar_data['perihelion'].astype(float)
aphelion = solar_data['aphelion'].astype(float)
# Out:
# (20, 11)
#                 Attribute Mercury  Venus  Earth   Moon   Mars Jupiter  Saturn  \
# 0          Mass (10^24kg)   0.330   4.87   5.97  0.073  0.642    1898     568
# 1           Diameter (km)    4879  12104  12756   3475   6792  142984  120536
# 2        Density (kg/m^3)    5429   5243   5514   3340   3934    1326     687
# 3         Gravity (m/s^2)     3.7    8.9    9.8    1.6    3.7    23.1     9.0
# 4  Escape Velocity (km/s)     4.3   10.4   11.2    2.4    5.0    59.5    35.5
#
#   Uranus Neptune   Pluto
# 0   86.8     102  0.0130
# 1  51118   49528    2376
# 2   1270    1638    1850
# 3    8.7    11.0     0.7
# 4   21.3    23.5     1.3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# ...

# %%
print(solar_data.columns)
# Out:
# Index(['Attribute', 'Mercury', 'Venus', 'Earth', 'Moon', 'Mars', 'Jupiter',
#        'Saturn', 'Uranus', 'Neptune', 'Pluto'],
#       dtype='object')

# %%
#3.6
"""
Orbital period: how long the planet takes to complete one orbit
Perihelion: closest distance to the sun
Aphelion: furthest distance to the sun i
"""
